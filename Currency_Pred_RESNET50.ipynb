# %% [markdown]
# <a href="https://colab.research.google.com/github/Soumedhik/Blind-Aid-Intel_OneApi_Hackathon/blob/main/Currency_Pred_RESNET50.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES
# TO THE CORRECT LOCATION (/kaggle/input) IN YOUR NOTEBOOK,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.

import os
import sys
from tempfile import NamedTemporaryFile
from urllib.request import urlopen
from urllib.parse import unquote, urlparse
from urllib.error import HTTPError
from zipfile import ZipFile
import tarfile
import shutil

CHUNK_SIZE = 40960
DATA_SOURCE_MAPPING = 'resnet50:https%3A%2F%2Fstorage.googleapis.com%2Fkaggle-data-sets%2F6209%2F9900%2Fbundle%2Farchive.zip%3FX-Goog-Algorithm%3DGOOG4-RSA-SHA256%26X-Goog-Credential%3Dgcp-kaggle-com%2540kaggle-161607.iam.gserviceaccount.com%252F20240329%252Fauto%252Fstorage%252Fgoog4_request%26X-Goog-Date%3D20240329T214509Z%26X-Goog-Expires%3D259200%26X-Goog-SignedHeaders%3Dhost%26X-Goog-Signature%...,indian-currency-note-images-dataset-2020:https%3A%2F%2Fstorage.googleapis.com%2Fkaggle-data-sets%2F886101%2F1505106%2Fbundle%2Farchive.zip%3FX-Goog-Algorithm%3DGOOG4-RSA-SHA256%26X-Goog-Credential%3Dgcp-kaggle-com%2540kaggle-161607.iam.gserviceaccount.com%252F20240329%252Fauto%252Fstorage%252Fgoog4_request%26X-Goog-Date%3D20240329T214509Z%26X-Goog-Expires%3D259200%26X-Goog-SignedHeaders%3Dhost%26X-Goog-Signature%...,indian-currency-note-resnet-weights:https%3A%2F%2Fstorage.googleapis.com%2Fkaggle-data-sets%2F886652%2F1505707%2Fbundle%2Farchive.zip%3FX-Goog-Algorithm%3DGOOG4-RSA-SHA256%26X-Goog-Credential%3Dgcp-kaggle-com%2540kaggle-161607.iam.gserviceaccount.com%252F20240329%252Fauto%252Fstorage%252Fgoog4_request%26X-Goog-Date%3D20240329T214509Z%26X-Goog-Expires%3D259200%26X-Goog-SignedHeaders%3Dhost%26X-Goog-Signature%...'

KAGGLE_INPUT_PATH='/kaggle/input'
KAGGLE_WORKING_PATH='/kaggle/working'
KAGGLE_SYMLINK='kaggle'

# !umount /kaggle/input/ 2> /dev/null
shutil.rmtree('/kaggle/input', ignore_errors=True)
os.makedirs(KAGGLE_INPUT_PATH, 0o777, exist_ok=True)
os.makedirs(KAGGLE_WORKING_PATH, 0o777, exist_ok=True)

try:
  os.symlink(KAGGLE_INPUT_PATH, os.path.join("..", 'input'), target_is_directory=True)
except FileExistsError:
  pass
try:
  os.symlink(KAGGLE_WORKING_PATH, os.path.join("..", 'working'), target_is_directory=True)
except FileExistsError:
  pass

for data_source_mapping in DATA_SOURCE_MAPPING.split(','):
    directory, download_url_encoded = data_source_mapping.split(':')
    download_url = unquote(download_url_encoded)
    filename = urlparse(download_url).path
    destination_path = os.path.join(KAGGLE_INPUT_PATH, directory)
    try:
        with urlopen(download_url) as fileres, NamedTemporaryFile() as tfile:
            total_length = fileres.headers['content-length']
            print(f'Downloading {directory}, {total_length} bytes compressed')
            dl = 0
            data = fileres.read(CHUNK_SIZE)
            while len(data) > 0:
                dl += len(data)
                tfile.write(data)
                done = int(50 * dl / int(total_length))
                sys.stdout.write(f"\r[{'=' * done}{' ' * (50-done)}] {dl} bytes downloaded")
                sys.stdout.flush()
                data = fileres.read(CHUNK_SIZE)
            if filename.endswith('.zip'):
              with ZipFile(tfile) as zfile:
                zfile.extractall(destination_path)
            else:
              with tarfile.open(tfile.name) as tarfile:
                tarfile.extractall(destination_path)
            print(f'\nDownloaded and uncompressed: {directory}')
    except HTTPError as e:
        print(f'Failed to load (likely expired) {download_url} to path {destination_path}')
        continue
    except OSError as e:
        print(f'Failed to load {download_url} to path {destination_path}')
        continue

print('Data source import complete.')
# Out:
# Downloading resnet50, 182711136 bytes compressed
# [==================================================] 182711136 bytes downloaded
# Downloaded and uncompressed: resnet50
# Downloading indian-currency-note-images-dataset-2020, 2482345188 bytes compressed
# [==================================================] 2482345188 bytes downloaded
# Downloaded and uncompressed: indian-currency-note-images-dataset-2020
# Downloading indian-currency-note-resnet-weights, 87709370 bytes compressed
# [==================================================] 87709370 bytes downloaded
# Downloaded and uncompressed: indian-currency-note-resnet-weights
# Data source import complete.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/resnet50/imagenet_class_index.json
# /kaggle/input/resnet50/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# /kaggle/input/resnet50/resnet50_weights_tf_dim_ordering_tf_kernels.h5
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/100__371.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/500__289.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/Background__309.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/500__114.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/2000__114.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/100_3.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/10__324.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/20__324.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/Background__311.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/50__408.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/50__148.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/100__389.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/50__274.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/200.__143.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/2000__288.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/20__9.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/10__358.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/200.__192.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/2000__8.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/100_359.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/20__295.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/100__437.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/500__262.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/2000__37.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/Background__303.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/100_371.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/2000__317.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/20__350.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/100_4.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/10__276.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/20__72.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/100__435.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/200.__338.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/50__295.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/50__345.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/50__366.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/20__226.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/200.__225.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/50__288.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/500__331.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/200.__290.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/500__37.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/200.__87.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/200.__142.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/2000__161.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/200.__37.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/200.__492.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/Background__302.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/Background__304.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/50__147.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/10__388.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/2000__66.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/10__443.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/200.__170.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/2000__428.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/20__415.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/500__0.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/20__107.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/Background__310.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/200.__1.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/100__415.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/Background__305.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/20__65.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/20__136.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/50__213.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/50__267.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/200.__17.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/20__36.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/20__449.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/50__183.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/500__57.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/100__386.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/2000__261.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/10__206.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/100__427.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/200.__254.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/500__233.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/100_270.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/500__17.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/50__338.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/2000__359.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/50__442.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/Background__312.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/2000__240.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/500__429.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/200.__206.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/100_15.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/10__247.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/100_20.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/200.__402.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/test/500__374.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/20/20_val_29.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/20/20_val_37.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/20/20_val_11.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/20/20_val_12.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/20/20_val_3.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/20/20_val_19.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/20/20_val_1.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/20/20_val_42.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/20/20_val_43.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/20/20_val_20.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/20/20_val_28.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/20/20_val_32.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/20/20_val_0.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/20/20_val_5.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/20/20_val_8.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/20/20_val_36.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/20/20_val_18.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/20/20_val_38.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/20/20_val_16.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/20/20_val_17.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/20/20_val_2.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/20/20_val_27.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/20/20_val_33.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/20/20_val_44.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/20/20_val_24.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/20/20_val_15.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/20/20_val_4.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/20/20_val_41.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/20/20_val_9.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/20/20_val_22.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/20/20_val_10.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/20/20_val_7.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/20/20_val_39.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/20/20_val_31.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/20/20_val_26.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/20/20_val_23.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/20/20_val_35.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/20/20_val_30.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/20/20_val_40.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/20/20_val_21.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/20/20_val_6.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/20/20_val_25.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/20/20_val_34.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/20/20_val_13.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/20/20_val_14.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/100/100_val_20.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/100/100_val_3.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/100/100_val_39.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/100/100_val_15.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/100/100_val_25.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/100/100_val_41.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/100/100_val_17.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/100/100_val_27.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/100/100_val_24.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/100/100_val_43.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/100/100_val_44.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/100/100_val_42.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/100/100_val_9.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/100/100_val_14.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/100/100_val_31.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/100/100_val_38.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/100/100_val_36.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/100/100_val_13.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/100/100_val_33.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/100/100_val_30.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/100/100_val_0.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/100/100_val_29.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/100/100_val_40.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/100/100_val_19.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/100/100_val_1.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/100/100_val_28.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/100/100_val_7.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/100/100_val_21.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/100/100_val_11.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/100/100_val_12.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/100/100_val_6.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/100/100_val_18.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/100/100_val_32.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/100/100_val_10.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/100/100_val_35.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/100/100_val_8.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/100/100_val_4.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/100/100_val_23.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/100/100_val_5.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/100/100_val_22.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/100/100_val_2.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/100/100_val_16.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/100/100_val_37.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/100/100_val_34.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/100/100_val_26.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/Background/Background_val_11.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/Background/Background_val_23.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/Background/Background_val_2.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/Background/Background_val_22.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/Background/Background_val_17.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/Background/Background_val_4.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/Background/Background_val_13.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/Background/Background_val_12.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/Background/Background_val_6.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/Background/Background_val_10.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/Background/Background_val_7.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/Background/Background_val_5.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/Background/Background_val_24.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/Background/Background_val_29.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/Background/Background_val_15.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/Background/Background_val_3.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/Background/Background_val_0.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/Background/Background_val_14.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/Background/Background_val_8.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/Background/Background_val_1.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/Background/Background_val_9.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/Background/Background_val_25.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/Background/Background_val_19.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/Background/Background_val_18.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/Background/Background_val_26.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/Background/Background_val_28.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/Background/Background_val_16.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/Background/Background_val_21.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/Background/Background_val_20.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/Background/Background_val_27.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/500/500_val_43.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/500/500_val_36.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/500/500_val_21.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/500/500_val_11.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/500/500_val_44.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/500/500_val_7.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/500/500_val_25.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/500/500_val_20.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/500/500_val_26.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/500/500_val_41.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/500/500_val_42.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/500/500_val_15.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/500/500_val_37.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/500/500_val_12.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/500/500_val_5.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/500/500_val_23.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/500/500_val_17.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/500/500_val_27.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/500/500_val_30.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/500/500_val_24.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/500/500_val_33.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/500/500_val_3.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/500/500_val_40.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/500/500_val_1.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/500/500_val_18.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/500/500_val_13.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/500/500_val_16.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/500/500_val_38.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/500/500_val_6.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/500/500_val_29.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/500/500_val_22.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/500/500_val_39.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/500/500_val_34.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/500/500_val_9.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/500/500_val_14.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/500/500_val_10.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/500/500_val_19.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/500/500_val_2.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/500/500_val_28.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/500/500_val_35.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/500/500_val_8.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/500/500_val_31.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/500/500_val_0.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/500/500_val_4.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/500/500_val_32.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/2000/2000_val_43.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/2000/2000_val_8.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/2000/2000_val_22.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/2000/2000_val_42.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/2000/2000_val_3.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/2000/2000_val_12.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/2000/2000_val_7.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/2000/2000_val_4.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/2000/2000_val_36.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/2000/2000_val_23.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/2000/2000_val_44.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/2000/2000_val_9.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/2000/2000_val_2.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/2000/2000_val_31.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/2000/2000_val_6.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/2000/2000_val_35.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/2000/2000_val_38.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/2000/2000_val_39.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/2000/2000_val_25.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/2000/2000_val_14.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/2000/2000_val_40.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/2000/2000_val_26.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/2000/2000_val_32.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/2000/2000_val_33.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/2000/2000_val_37.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/2000/2000_val_15.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/2000/2000_val_24.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/2000/2000_val_21.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/2000/2000_val_30.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/2000/2000_val_17.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/2000/2000_val_5.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/2000/2000_val_1.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/2000/2000_val_20.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/2000/2000_val_41.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/2000/2000_val_19.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/2000/2000_val_10.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/2000/2000_val_0.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/2000/2000_val_34.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/2000/2000_val_28.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/2000/2000_val_11.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/2000/2000_val_29.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/2000/2000_val_16.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/2000/2000_val_18.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/2000/2000_val_13.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/2000/2000_val_27.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/200/200_val_1.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/200/200_val_18.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/200/200_val_13.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/200/200_val_43.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/200/200_val_19.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/200/200_val_3.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/200/200_val_36.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/200/200_val_42.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/200/200_val_35.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/200/200_val_34.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/200/200_val_21.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/200/200_val_31.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/200/200_val_15.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/200/200_val_14.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/200/200_val_26.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/200/200_val_27.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/200/200_val_33.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/200/200_val_32.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/200/200_val_7.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/200/200_val_39.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/200/200_val_23.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/200/200_val_25.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/200/200_val_24.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/200/200_val_22.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/200/200_val_10.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/200/200_val_6.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/200/200_val_12.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/200/200_val_2.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/200/200_val_44.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/200/200_val_40.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/200/200_val_0.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/200/200_val_29.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/200/200_val_5.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/200/200_val_11.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/200/200_val_16.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/200/200_val_9.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/200/200_val_8.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/200/200_val_20.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/200/200_val_37.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/200/200_val_4.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/200/200_val_30.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/200/200_val_38.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/200/200_val_41.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/200/200_val_17.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/200/200_val_28.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/10/10_val_12.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/10/10_val_28.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/10/10_val_33.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/10/10_val_21.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/10/10_val_40.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/10/10_val_19.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/10/10_val_4.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/10/10_val_15.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/10/10_val_23.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/10/10_val_24.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/10/10_val_42.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/10/10_val_26.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/10/10_val_3.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/10/10_val_27.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/10/10_val_20.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/10/10_val_8.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/10/10_val_6.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/10/10_val_43.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/10/10_val_22.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/10/10_val_34.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/10/10_val_41.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/10/10_val_29.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/10/10_val_37.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/10/10_val_2.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/10/10_val_14.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/10/10_val_5.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/10/10_val_44.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/10/10_val_36.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/10/10_val_31.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/10/10_val_13.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/10/10_val_17.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/10/10_val_18.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/10/10_val_11.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/10/10_val_0.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/10/10_val_39.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/10/10_val_16.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/10/10_val_30.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/10/10_val_7.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/10/10_val_35.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/10/10_val_10.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/10/10_val_9.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/10/10_val_32.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/10/10_val_1.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/10/10_val_25.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/10/10_val_38.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/50/50_val_29.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/50/50_val_44.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/50/50_val_37.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/50/50_val_34.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/50/50_val_25.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/50/50_val_30.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/50/50_val_20.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/50/50_val_35.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/50/50_val_9.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/50/50_val_33.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/50/50_val_7.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/50/50_val_14.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/50/50_val_22.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/50/50_val_24.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/50/50_val_43.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/50/50_val_19.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/50/50_val_38.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/50/50_val_39.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/50/50_val_8.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/50/50_val_26.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/50/50_val_32.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/50/50_val_2.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/50/50_val_36.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/50/50_val_16.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/50/50_val_0.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/50/50_val_6.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/50/50_val_5.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/50/50_val_31.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/50/50_val_27.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/50/50_val_12.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/50/50_val_10.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/50/50_val_13.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/50/50_val_11.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/50/50_val_1.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/50/50_val_3.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/50/50_val_23.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/50/50_val_15.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/50/50_val_28.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/50/50_val_4.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/50/50_val_17.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/50/50_val_18.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/50/50_val_41.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/validation/50/50_val_42.jpg
# ...
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__96.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__225.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__224.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__397.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__321.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__410.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__407.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__218.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__389.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__435.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__270.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__236.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__85.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__127.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__31.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__205.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__21.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__347.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__213.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__314.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__210.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__367.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__326.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__404.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__101.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__267.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__392.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__244.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__434.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__40.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__247.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__272.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__446.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__332.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__339.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__382.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__214.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__190.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__424.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__371.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__230.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__234.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__284.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__317.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__100.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__262.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__242.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__273.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__221.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__440.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__426.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__154.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__141.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__353.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__183.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__64.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__354.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__50.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__278.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__248.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__142.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__61.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__351.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__200.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__429.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__207.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__331.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__37.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__430.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__114.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__173.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__402.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__60.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__136.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__355.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__393.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__201.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__2.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__259.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__189.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__318.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__396.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__62.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__320.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__287.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__302.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__357.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__409.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__377.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__167.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__41.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__140.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__400.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__219.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__75.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__150.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__283.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__266.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__293.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__364.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__116.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__185.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__92.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__268.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__203.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__229.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__238.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__432.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__99.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__436.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__437.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__217.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__360.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__222.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__39.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__338.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__15.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__411.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__306.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__383.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__125.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__442.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__25.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__406.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__330.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__130.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__427.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__413.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__73.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__22.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__391.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__158.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__245.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__181.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__0.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__113.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__220.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__335.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__374.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__333.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__251.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__337.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__162.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__443.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__6.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__381.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__334.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__28.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__252.jpg
# /kaggle/input/indian-currency-note-images-dataset-2020/Indian currency dataset v1/training/50/50__227.jpg
# /kaggle/input/indian-currency-note-resnet-weights/currency_detector_2.4GB_earlyStopping_model.h5

# %%
pip install path
# Out:
# Collecting path
#   Downloading path-16.10.0-py3-none-any.whl (25 kB)
# Installing collected packages: path
# Successfully installed path-16.10.0

# %%
#import basic essential libraries
import matplotlib.pyplot as plt
import path
import os
# %matplotlib inline

# import  keras libraries to build model and conv net
import tensorflow as tf
from tensorflow.python import keras
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense,Conv2D,MaxPooling2D,Dropout,Flatten
from pathlib import Path

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator


data_agumentation=ImageDataGenerator(rescale=0./255,
                             shear_range=0.2,
                             zoom_range=0.2,
                             horizontal_flip=True,
                             vertical_flip=True

)

# %%
from tensorflow.keras.models import load_model

model=load_model('../input/indian-currency-note-resnet-weights/currency_detector_2.4GB_earlyStopping_model.h5')

# %%
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %%
from tensorflow.keras.utils import plot_model
# Display the model diagram
plot_model(model, to_file='model_diagram.png', show_shapes=True, show_layer_names=True)

# %%
from keras.preprocessing import image
class_labels = [
    '10','100','20','200','2000','50','500','Background'
]

def prediction(file_name):
    img = image.load_img(file_name, target_size=(256,256))

    image_to_test = image.img_to_array(img)

    # Since Keras expects a list of images, not a single image,
    # Add a fourth dimension to the image
    list_of_images = np.expand_dims(image_to_test, axis=0)

    # Make a prediction using the model
    results = model.predict(list_of_images)

    # Since we are only testing one image, we only need to check the first result
    single_result = results[0]

    # We will get a likelihood score for all possible classes.
    # Find out which class had the highest score.
    # The class with the highest likelihood is predicted as the result.
    most_likely_class_index = int(np.argmax(single_result))
    class_likelihood = single_result[most_likely_class_index]

    # Get the name of the most likely class
    class_label = class_labels[most_likely_class_index]

    # Print the result
    print(file_name)
    print("This image is predicted as a {} with a likelihood of {:.2f}".format(class_label, class_likelihood))

# %%
prediction("/content/360_F_356320611_FcuF3JcK9DIkAAPS8kbtHxZx8iS4Je8P.jpg")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-cb6118532ac5> in <cell line: 1>()
# ----> 1 prediction("/content/360_F_356320611_FcuF3JcK9DIkAAPS8kbtHxZx8iS4Je8P.jpg")
#
# <ipython-input-10-97c236fb0629> in prediction(file_name)
#       5
#       6 def prediction(file_name):
# ----> 7     img = image.load_img(file_name, target_size=(256,256))
#       8
#       9     image_to_test = image.img_to_array(img)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/image_utils.py in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     420         if isinstance(path, pathlib.Path):
#     421             path = str(path.resolve())
# --> 422         with open(path, "rb") as f:
#     423             img = pil_image.open(io.BytesIO(f.read()))
#     424     else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/360_F_356320611_FcuF3JcK9DIkAAPS8kbtHxZx8iS4Je8P.jpg'

# %%
# !pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.32.2-py2.py3-none-any.whl (8.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 24.5 MB/s eta 0:00:00
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (4.2.2)
# Requirement already satisfied: blinker<2,>=1.0.0 in /usr/lib/python3/dist-packages (from streamlit) (1.4)
# Requirement already satisfied: cachetools<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<2,>=1.19.3 in /usr/local/lib/python3.10/dist-packages (from streamlit) (1.25.2)
# Collecting packaging<24,>=16.8 (from streamlit)
#   Downloading packaging-23.2-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: pandas<3,>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (1.5.3)
# Requirement already satisfied: pillow<11,>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (9.4.0)
# Requirement already satisfied: protobuf<5,>=3.20 in /usr/local/lib/python3.10/dist-packages (from streamlit) (3.20.3)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (14.0.2)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.10/dist-packages (from streamlit) (2.31.0)
# Requirement already satisfied: rich<14,>=10.14.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (8.2.3)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (4.10.0)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Downloading GitPython-3.1.42-py3-none-any.whl (195 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 18.6 MB/s eta 0:00:00
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.8.1b0-py2.py3-none-any.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 35.5 MB/s eta 0:00:00
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.10/dist-packages (from streamlit) (6.3.3)
# Collecting watchdog>=2.1.5 (from streamlit)
#   Downloading watchdog-4.0.0-py3-none-manylinux2014_x86_64.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (0.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (3.1.3)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (4.19.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (0.12.1)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.3.0->streamlit) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.3.0->streamlit) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (2024.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit) (2.16.1)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.34.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas<3,>=1.3.0->streamlit) (1.16.0)
# Installing collected packages: watchdog, smmap, packaging, pydeck, gitdb, gitpython, streamlit
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
# Successfully installed gitdb-4.0.11 gitpython-3.1.42 packaging-23.2 pydeck-0.8.1b0 smmap-5.0.1 streamlit-1.32.2 watchdog-4.0.0

# %%
# %%writefile app.py
import streamlit as st
import numpy as np
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import load_model

# Load the pre-trained model
model = load_model('../input/indian-currency-note-resnet-weights/currency_detector_2.4GB_earlyStopping_model.h5')
class_labels = ['10', '100', '20', '200', '2000', '50', '500', 'Background']

def predict_currency(image_file):
    img = image.load_img(image_file, target_size=(256, 256))
    image_to_test = image.img_to_array(img)
    list_of_images = np.expand_dims(image_to_test, axis=0)
    results = model.predict(list_of_images)
    most_likely_class_index = int(np.argmax(results[0]))
    class_likelihood = results[0][most_likely_class_index]
    class_label = class_labels[most_likely_class_index]
    return class_label, class_likelihood

def main():
    st.title("Indian Currency Note Detector")
    uploaded_file = st.file_uploader("Upload an image of an Indian currency note", type=["jpg", "jpeg", "png"])

    if uploaded_file:
        class_label, class_likelihood = predict_currency(uploaded_file)
        st.image(uploaded_file, caption=f"Predicted as {class_label} with likelihood {class_likelihood:.2f}")
        st.write(f"This image is predicted as a {class_label} with a likelihood of {class_likelihood:.2f}")

if __name__ == "__main__":
    main()
# Out:
# Writing app.py

# %%
# !npm install localtunnel
# Out:
# npm WARN saveError ENOENT: no such file or directory, open '/content/package.json'
# npm notice created a lockfile as package-lock.json. You should commit this file.
# npm WARN enoent ENOENT: no such file or directory, open '/content/package.json'
# npm WARN content No description
# npm WARN content No repository field.
# npm WARN content No README data
# npm WARN content No license field.
#
# + localtunnel@2.0.2
# added 22 packages from 22 contributors and audited 22 packages in 2.482s
#
# 3 packages are looking for funding
#   run `npm fund` for details
#
# found 1 moderate severity vulnerability
#   run `npm audit fix` to fix them, or `npm audit` for details

# %%
! wget -q -O - ipv4.icanhazip.com
# Out:
# 34.73.38.231

# %%
! streamlit run app.py & npx localtunnel --port 8501
# Out:
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to False.
#
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.73.38.231:8501
#
# npx: installed 22 in 2.386s
# your url is: https://late-oranges-ask.loca.lt
# 2024-03-30 09:39:32.426210: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-30 09:39:32.426280: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-30 09:39:32.431296: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-30 09:39:33.979403: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-03-30 09:40:28.642 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 542, in _run_script
#     exec(code, module.__dict__)
#   File "/content/app.py", line 65, in <module>
#     main()
#   File "/content/app.py", line 47, in main
#     uploaded_file = st.file_uploader("Upload an image of an Indian currency note", type=["jpg", "jpeg", "png"])
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/metrics_util.py", line 397, in wrapped_func
#     result = non_optional_func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/elements/widgets/file_uploader.py", line 371, in file_uploader
#     return self._file_uploader(
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/elements/widgets/file_uploader.py", line 458, in _file_uploader
#     widget_state = register_widget(
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/state/widgets.py", line 163, in register_widget
#     return register_widget_from_metadata(metadata, ctx, widget_func_name, element_type)
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/state/widgets.py", line 208, in register_widget_from_metadata
#     raise DuplicateWidgetID(
# streamlit.errors.DuplicateWidgetID: There are multiple identical `st.file_uploader` widgets with the
# same generated key.
#
# When a widget is created, it's assigned an internal key based on
# its structure. Multiple widgets with an identical structure will
# result in the same internal key, which causes this error.
#
# To fix this error, please pass a unique `key` argument to
# `st.file_uploader`.
# 1/1 [==============================] - 1s 1s/step
# 2024-03-30 09:40:43.441 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 542, in _run_script
#     exec(code, module.__dict__)
#   File "/content/app.py", line 65, in <module>
#     main()
#   File "/content/app.py", line 47, in main
#     uploaded_file = st.file_uploader("Upload an image of an Indian currency note", type=["jpg", "jpeg", "png"])
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/metrics_util.py", line 397, in wrapped_func
#     result = non_optional_func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/elements/widgets/file_uploader.py", line 371, in file_uploader
#     return self._file_uploader(
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/elements/widgets/file_uploader.py", line 458, in _file_uploader
#     widget_state = register_widget(
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/state/widgets.py", line 163, in register_widget
#     return register_widget_from_metadata(metadata, ctx, widget_func_name, element_type)
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/state/widgets.py", line 208, in register_widget_from_metadata
#     raise DuplicateWidgetID(
# streamlit.errors.DuplicateWidgetID: There are multiple identical `st.file_uploader` widgets with the
# same generated key.
#
# When a widget is created, it's assigned an internal key based on
# its structure. Multiple widgets with an identical structure will
# result in the same internal key, which causes this error.
#
# To fix this error, please pass a unique `key` argument to
# `st.file_uploader`.
# 1/1 [==============================] - 3s 3s/step
# 2024-03-30 09:41:01.610 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 542, in _run_script
#     exec(code, module.__dict__)
#   File "/content/app.py", line 65, in <module>
#     main()
#   File "/content/app.py", line 47, in main
#     uploaded_file = st.file_uploader("Upload an image of an Indian currency note", type=["jpg", "jpeg", "png"])
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/metrics_util.py", line 397, in wrapped_func
#     result = non_optional_func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/elements/widgets/file_uploader.py", line 371, in file_uploader
#     return self._file_uploader(
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/elements/widgets/file_uploader.py", line 458, in _file_uploader
#     widget_state = register_widget(
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/state/widgets.py", line 163, in register_widget
#     return register_widget_from_metadata(metadata, ctx, widget_func_name, element_type)
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/state/widgets.py", line 208, in register_widget_from_metadata
#     raise DuplicateWidgetID(
# streamlit.errors.DuplicateWidgetID: There are multiple identical `st.file_uploader` widgets with the
# same generated key.
#
# When a widget is created, it's assigned an internal key based on
# its structure. Multiple widgets with an identical structure will
# result in the same internal key, which causes this error.
#
# To fix this error, please pass a unique `key` argument to
# `st.file_uploader`.
#   Stopping...
# ^C

# %%
# !pip install git+https://github.com/openai/whisper.git
# Out:
# Collecting git+https://github.com/openai/whisper.git
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-03n1bt9z
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-03n1bt9z
#   Resolved https://github.com/openai/whisper.git to commit ba3f3cd54b0e5b8ce1ab3de13e32122d0d5f98ab
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20231117) (0.58.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20231117) (1.25.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20231117) (2.2.1+cu121)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20231117) (4.66.2)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20231117) (10.1.0)
# Collecting tiktoken (from openai-whisper==20231117)
#   Downloading tiktoken-0.6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 10.5 MB/s eta 0:00:00
# Requirement already satisfied: triton<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20231117) (2.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from triton<3,>=2.0.0->openai-whisper==20231117) (3.13.3)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->openai-whisper==20231117) (0.41.1)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken->openai-whisper==20231117) (2023.12.25)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from tiktoken->openai-whisper==20231117) (2.31.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20231117) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20231117) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20231117) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20231117) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20231117) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch->openai-whisper==20231117)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 24.6 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch->openai-whisper==20231117)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 31.6 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch->openai-whisper==20231117)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 33.5 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch->openai-whisper==20231117)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.4 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch->openai-whisper==20231117)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.2 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch->openai-whisper==20231117)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 7.5 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch->openai-whisper==20231117)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 11.2 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch->openai-whisper==20231117)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.3 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch->openai-whisper==20231117)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 2.2 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.19.3 (from torch->openai-whisper==20231117)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 2.4 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch->openai-whisper==20231117)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 12.4 MB/s eta 0:00:00
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch->openai-whisper==20231117)
#   Downloading nvidia_nvjitlink_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 56.4 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20231117) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20231117) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20231117) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20231117) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->openai-whisper==20231117) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->openai-whisper==20231117) (1.3.0)
# Building wheels for collected packages: openai-whisper
#   Building wheel for openai-whisper (pyproject.toml) ... done
#   Created wheel for openai-whisper: filename=openai_whisper-20231117-py3-none-any.whl size=802826 sha256=216a22648d1187563a323a11f86f3601accacc999200f9fe7d311d89b80ca653
#   Stored in directory: /tmp/pip-ephem-wheel-cache-vtnwdvg1/wheels/8b/6c/d0/622666868c179f156cf595c8b6f06f88bc5d80c4b31dccaa03
# Successfully built openai-whisper
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, tiktoken, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, openai-whisper
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.99 nvidia-nvtx-cu12-12.1.105 openai-whisper-20231117 tiktoken-0.6.0

# %%
# !pip install --upgrade --no-deps --force-reinstall git+https://github.com/openai/whisper.git
# Out:
# Collecting git+https://github.com/openai/whisper.git
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-exaa8uzn
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-exaa8uzn
#   Resolved https://github.com/openai/whisper.git to commit ba3f3cd54b0e5b8ce1ab3de13e32122d0d5f98ab
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: openai-whisper
#   Building wheel for openai-whisper (pyproject.toml) ... done
#   Created wheel for openai-whisper: filename=openai_whisper-20231117-py3-none-any.whl size=802826 sha256=9381ccc27135953d53c2bddd4fb276e799208bafdb63c57b8dc1d2b7f7575bea
#   Stored in directory: /tmp/pip-ephem-wheel-cache-zix3aepp/wheels/8b/6c/d0/622666868c179f156cf595c8b6f06f88bc5d80c4b31dccaa03
# Successfully built openai-whisper
# Installing collected packages: openai-whisper
#   Attempting uninstall: openai-whisper
#     Found existing installation: openai-whisper 20231117
#     Uninstalling openai-whisper-20231117:
#       Successfully uninstalled openai-whisper-20231117
# Successfully installed openai-whisper-20231117

# %%
# !sudo apt update && sudo apt install ffmpeg
# Out:
# Hit:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:7 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [1,920 kB]
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,358 kB]
# Fetched 3,510 kB in 2s (2,287 kB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 49 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.

# %%
# !whisper "/content/Recording.m4a" --model base
# Out:
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Detecting language using up to the first 30 seconds. Use `--language` to specify the language
# Detected language: English
# [00:00.000 --> 00:02.000]  CD, find me 140 rupees.

# %%
import subprocess
import re

# Transcribe the audio using Whisper
audio_file = "/content/Recording.m4a"
transcription = subprocess.check_output(["whisper", audio_file, "--model", "base", "--word_timestamps", "True"]).decode("utf-8")

# Extract the number mentioned after "find me"
match = re.search(r'find me (\d+)', transcription)
if match:
    number = int(match.group(1))
    print("Extracted number:", number)
else:
    print("No number found in the transcription.")
# Out:
# Extracted number: 140

# %%
# Step 1: Create the array of tuples with duplicate denominations
original_array = []
total_amount = int(input("Enter the total amount of notes: "))
for _ in range(num_notes):
    uploaded_file = st.file_uploader("Upload an image of an Indian currency note", type=["jpg", "jpeg", "png"])
    if uploaded_file:
            img = image.load_img(image_file, target_size=(256, 256))
            image_to_test = image.img_to_array(img)
            list_of_images = np.expand_dims(image_to_test, axis=0)
            results = model.predict(list_of_images)
            most_likely_class_index = int(np.argmax(results[0]))
            class_likelihood = results[0][most_likely_class_index]
            class_label = class_labels[most_likely_class_index]
            original_array.append(int(class_label))
indexed_array = [(value, index + 1) for index, value in enumerate(original_array)]

# Step 2: Sort the array based on the first element of each tuple (the value) in descending order
sorted_array = sorted(indexed_array, key=lambda x: x[0], reverse=True)

total_amount = int(input("Enter the total amount: "))

# Step 3: Initialize variables to track the total and the notes included
remaining_amount = total_amount
included_notes = []

# Step 4: Iterate through the sorted array and calculate the best denominations
for denomination, index in sorted_array:
    count = remaining_amount // denomination
    if count > 0:
        included_notes.extend([(denomination, index)] * count)
        remaining_amount %= denomination

# Step 5: Display the included notes with their original positions
print("Denominations:")
for denomination, index in included_notes:
    print(f"Note of {denomination} rs from position {index}")

# Step 6: Display the remaining change (if any)
if remaining_amount > 0:
    print(f"Remaining change: {remaining_amount} rs")
# Out:
#   File "<tokenize>", line 8
#     image_to_test = image.img_to_array(img)
#     ^
# IndentationError: unindent does not match any outer indentation level
